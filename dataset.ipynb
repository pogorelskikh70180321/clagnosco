# %% [markdown]
# Датасет

# %%
from datasets import load_dataset
import pandas as pd
import os

# Основаная папка для сохранений
save_dir = r"C:\!project-dataset"
os.makedirs(save_dir, exist_ok=True)

# Загрузка датасета
dataset = load_dataset("Salesforce/blip3-kale", name="core", split="train", streaming=True)

# Пареметры сохранения
batch_size = 50000
file_index = 0

batch = []
for idx, example in enumerate(dataset, 1):
    try:
        batch.append(example)

        if idx % batch_size == 0:
            df = pd.DataFrame(batch)
            file_path = os.path.join(save_dir, f"blip3-kale_part_{file_index:08d}.parquet")
            df.to_parquet(file_path, index=False)
            print(f"Saved {file_path}")
            batch = []
            file_index += 1
    except Exception as e:
        print(f"Ошибка с индексом {idx}: {e}")
        continue

# Сохранение
if batch:
    df = pd.DataFrame(batch)
    file_path = os.path.join(save_dir, f"blip3-kale_part_{file_index:08d}.parquet")
    df.to_parquet(file_path, index=False)
    print(f"Созранено {file_path}")

# %%
# Загрузка parquet
df = pd.read_parquet(r"C:\!project-dataset\blip3-kale_part_00000000.parquet")

print(df.columns)
print(df["url"][6])
df
# Out:
# Index(['uid', 'face_bboxes', 'caption', 'url', 'original_width',
#        'original_height', 'exif', 'sha256', 'datacomp_caption',
#        'cogvlm_caption'],
#       dtype='object')
# https://vignette2.wikia.nocookie.net/maxpayne/images/7/73/Max_Payne_2_Ch3_Blowing_Up_-_Part_2_A_Binary_Choice_Playthru/revision/latest/scale-to-width-down/330?cb=20160428050314
#                                   uid  \
# 0    02d33fa07cc81f77fd695ac5f3120b50
# 1    510f52a14e1b7e76849d3e5d93de837f
# 2    7885517e943624ee334faa0243e32223
# 3    c7a64d1d33794cce3b69cd3433822a57
# 4    0f9e0c209c8dbcd3cd36d2aebf9ba423
# ..                                ...
# 995  6f987f9369d073e50511095d3c169480
# 996  23f5c518dcd905bde19aed358a6d353a
# 997  3aaaf41aece22f46f9f8a74b6bed572d
# 998  eba1534200cc3ef3f01adb026fafc676
# 999  e5453acc4b24803abc102b30fc2f6d31
#
#                                            face_bboxes  \
# 0                                                   []
# ...

# %%
#Найти e5453acc4b24803abc102b30fc2f6d31
for i in df[df["uid"] == "e5453acc4b24803abc102b30fc2f6d31"].index:
    for j in df.columns:
        print(f"{j}: {df[j][i]}")
# Out:
# uid: e5453acc4b24803abc102b30fc2f6d31
# face_bboxes: []
# caption: In the image (476.4KB jpg by CREATOR_3D), a white Dacia Logan car is depicted in a frontal view, showcasing its crossover attributes with an elevated ground clearance, fog lights, and a prominent front grille displaying a logo. The headlights are large and round, and the bumper is equipped with fog lights and a central air intake, contributing to the car's sleek and modern design.
# url: https://assets.flatpyramid.com/wp-content/uploads/2017/07/11021629/dacia_logan_mcv_fiskal_2016-3d-model-41784-860307-1170x877.jpg
# original_width: 1170
# original_height: 877
# exif: {}
# sha256: 994be3d9d5a686f0a57379cf8d095e71dd921649f14fb76192179ecc16374954
# datacomp_caption: Dacia Logan MCV Fiskal 2016 ( 476.4KB jpg by CREATOR_3D )
# ...

# %%
# Скачивание изображений
import pandas as pd
import os
import requests
from PIL import Image
from io import BytesIO
from tqdm.notebook import tqdm
import glob
from concurrent.futures import ThreadPoolExecutor, as_completed

input_dir = r"C:\!project-dataset"
output_dir = os.path.join(input_dir, "images")
os.makedirs(output_dir, exist_ok=True)


def get_image_extension_from_bytes(image_bytes):
    try:
        img = Image.open(BytesIO(image_bytes))
        format_to_ext = {
            "JPEG": "jpg",
            "PNG": "png",
            "WEBP": "webp",
            "BMP": "bmp",
            "GIF": "gif"
        }
        return format_to_ext.get(img.format)
    except Exception as e:
        print(f"Not an image format: {e}")
        return None

def download_image(uid, url):
    if not uid or not url:
        return

    existing_files = [f for f in os.listdir(output_dir) if f.startswith(uid + ".")]
    if existing_files:
        return

    try:
        response = requests.get(url, timeout=10)
        if response.status_code == 200:
            ext = get_image_extension_from_bytes(response.content)
            if ext:
                file_path = os.path.join(output_dir, f"{uid}.{ext}")
                with open(file_path, "wb") as f:
                    f.write(response.content)
            else:
                print(f"Unknown format for {uid} from {url}")
        else:
            print(f"Failed {uid} ({response.status_code}): {url}")
    except Exception as e:
        print(f"Error downloading {uid} from {url}: {e}")


parquet_files = glob.glob(os.path.join(input_dir, "*.parquet"))

for parquet_file in tqdm(parquet_files[20:], desc="Parquet files"):
    print(f"\nProcessing: {os.path.basename(parquet_file)}")
    df = pd.read_parquet(parquet_file)

    # Фильтровать "original_width" и "original_height"
    filtered_rows = df[
        (df["original_width"] > 500) & 
        (df["original_height"] > 500)
    ]

    tasks = [(row["uid"], row["url"]) for _, row in filtered_rows.iterrows()]

    with ThreadPoolExecutor(max_workers=50) as executor:
        futures = [executor.submit(download_image, uid, url) for uid, url in tasks]

        for _ in tqdm(as_completed(futures), total=len(futures), desc="Downloading images", leave=False):
            pass

# %%
import os
import shutil
from PIL import Image
from collections import defaultdict
import hashlib

# Хэширование для поиска одинаковых по размеру файлов
def image_hash(filepath):
    try:
        with Image.open(filepath) as img:
            img = img.convert("RGB")
            data = img.tobytes()
            return hashlib.sha256(data).hexdigest()
    except Exception as e:
        print(f"Ошибка хэширования {filepath}: {e}")
        return None

# Директории - изначальная папка и папка с дубликатами
image_dir = r"C:\!project-dataset\images"
output_dir = r"C:\!project-dataset\duplicates_by_size"
os.makedirs(output_dir, exist_ok=True)

size_dict = defaultdict(list)
for root, dirs, files in os.walk(image_dir):
    for filename in files:
        filepath = os.path.join(root, filename)
        try:
            size = os.path.getsize(filepath)
            size_dict[size].append(filepath)
        except:
            print(f"Ошибка {filepath}")

# Поиск копий
for size, filepaths in size_dict.items():
    hash_dict = defaultdict(list)
    for f in filepaths:
        h = image_hash(f)
        if h:
            hash_dict[h].append(f)

    for h, duplicates in hash_dict.items():
        if len(duplicates) >= 2:
            size_folder = os.path.join(output_dir, str(size))
            os.makedirs(size_folder, exist_ok=True)
            for f in duplicates:
                filename = os.path.basename(f)

                dest_path_size = os.path.join(size_folder, filename)
                base, ext = os.path.splitext(filename)
                count = 1

                # Копирование в папку размеров
                while os.path.exists(dest_path_size):
                    dest_path_size = os.path.join(size_folder, f"{base}_{count}{ext}")
                    count += 1
                try:
                    shutil.copy2(f, dest_path_size)
                except Exception as e:
                    print(f"Ошибка копирования в папку размеров: {f} -> {dest_path_size}: {e}")

                # Копирование в общую папку
                dest_path_common = os.path.join(output_dir, filename)
                count = 1
                while os.path.exists(dest_path_common):
                    dest_path_common = os.path.join(output_dir, f"{base}_{count}{ext}")
                    count += 1
                try:
                    shutil.copy2(f, dest_path_common)
                except Exception as e:
                    print(f"Ошибка копирования в общую папку: {f} -> {dest_path_common}: {e}")

# %%
import os

image_dir = r"C:\!project-dataset\images"
output_dir = r"C:\!project-dataset\duplicates_by_size"

duplicate_filenames = os.listdir(output_dir)

# Удалить копии из основной папки
for filename in duplicate_filenames:
    image_path = os.path.join(image_dir, filename)
    if os.path.isfile(image_path):
        os.remove(image_path)
        # print(f"Удалено: {image_path}")
    else:
        print(f"Не найдено: {image_path}")

# %%
# Удаление если ширина или высота изображения меньше 512 или отношение больше 2.5
import os
from PIL import Image
from tqdm.notebook import tqdm

image_dir = r"C:\!project-dataset\images"
filenames = os.listdir(image_dir)
error_files = []

for filename in tqdm(filenames, desc="Обработка картинок"):
    image_path = os.path.join(image_dir, filename)
    try:
        with Image.open(image_path) as img:
            img = img.convert("RGB")
            width, height = img.size
            if min(width, height) < 512 or (max(width, height) / min(width, height) > 2.5):
                os.remove(image_path)
                print(f"Удалено: {image_path}")
    except Exception as e:
        error_files.append(filename)
        print(f"Ошибка обработки {image_path}: {e}")

# %%
# Удаление файлов с ошибками
for filename in error_files:
    image_path = os.path.join(image_dir, filename)
    if os.path.isfile(image_path):
        os.remove(image_path)
        print(f"Удалено: {image_path}")
    else:
        print(f"Файл не найден: {image_path}")

# %% [markdown]
# Изменение размера

# %%
import os
from PIL import Image
from tqdm.notebook import tqdm

image_dir = r"C:\!project-dataset\images"
image_resize_dir = r"C:\!project-dataset\images_resize"
os.makedirs(image_resize_dir, exist_ok=True)
image_square_dir = r"C:\!project-dataset\images_square"
os.makedirs(image_square_dir, exist_ok=True)
filenames = os.listdir(image_dir)
new_sizes = dict()
new_sizes_min_max = dict()
resize_size = 192  # минимум для сторон ресайза
square_size = 256  # размер квадратов

# Изменение размера картинок в новые файлы с JPG форматом
for image_file in tqdm(os.listdir(image_dir)):
    image_path = os.path.join(image_dir, image_file)
    resize_path = os.path.join(image_resize_dir, image_file.split(".")[0]+".jpg")
    sqaure_path = os.path.join(image_square_dir, image_file.split(".")[0]+".jpg")

    # Меньше картинки
    with Image.open(image_path) as img:
        img = img.convert("RGB")
        width, height = img.size

        if width < height:
            new_width = resize_size
            new_height = int((resize_size / width) * height)
        else:
            new_height = resize_size
            new_width = int((resize_size / height) * width)
        new_size = new_width, new_height
        
        if new_size in new_sizes:
            new_sizes[new_size] += 1
        else:
            new_sizes[new_size] = 1
        new_size_min_max = min(new_width, new_height), max(new_width, new_height)
        if new_size_min_max in new_sizes_min_max:
            new_sizes_min_max[new_size_min_max] += 1
        else:
            new_sizes_min_max[new_size_min_max] = 1

        img = img.resize(new_size, Image.LANCZOS)  # LANCZOS - лучше качество
        img.save(resize_path, "JPEG", quality=100, subsampling=0)
    
    # Квадраты
    with Image.open(image_path) as img:
        img = img.convert("RGB")
        img = img.resize((square_size, square_size), Image.LANCZOS)
        img.save(sqaure_path, "JPEG", quality=100, subsampling=0)

# %%
sorted(new_sizes_min_max.items(), key=lambda x: -x[1])
# Out:
# [((192, 192), 47046),
#  ((192, 256), 22402),
#  ((192, 288), 17865),
#  ((192, 287), 9360),
#  ((192, 341), 8539),
#  ((192, 255), 2895),
#  ((192, 240), 2382),
#  ((192, 289), 2028),
#  ((192, 248), 1587),
#  ((192, 271), 1196),
#  ((192, 261), 1118),
#  ((192, 307), 1092),
#  ((192, 245), 1049),
#  ((192, 286), 979),
#  ((192, 268), 966),
#  ((192, 257), 793),
#  ((192, 384), 738),
#  ((192, 241), 677),
#  ((192, 230), 669),
#  ((192, 277), 644),
#  ((192, 193), 644),
#  ((192, 224), 641),
#  ((192, 254), 637),
#  ((192, 294), 629),
#  ((192, 274), 598),
#  ((192, 290), 583),
#  ((192, 249), 550),
#  ((192, 320), 510),
#  ((192, 265), 496),
#  ((192, 196), 495),
#  ((192, 195), 491),
#  ((192, 239), 491),
#  ((192, 295), 489),
#  ((192, 259), 485),
#  ((191, 192), 484),
#  ((192, 202), 482),
#  ((192, 219), 477),
#  ((192, 251), 476),
#  ((192, 246), 476),
#  ((192, 247), 472),
#  ((192, 260), 471),
#  ((192, 340), 469),
#  ((192, 194), 469),
#  ((192, 269), 468),
# ...

# %% [markdown]
# Описание

# %%
import os
import glob
import pandas as pd
from tqdm.notebook import tqdm

parquet_dir = r"C:\!project-dataset"
parquet_files = glob.glob(os.path.join(parquet_dir, "*.parquet"))
parquet_files = parquet_files[:21]

# Обеденить все parquet в один дата фрейм
df = pd.concat([pd.read_parquet(f) for f in parquet_files], ignore_index=True)

print(f"Всего строк: {len(df)}")

# %%
image_dir = r"C:\!project-dataset\images"
caption_dir = r"C:\!project-dataset\captions"
os.makedirs(caption_dir, exist_ok=True)

uid_to_caption = dict(zip(df['uid'].astype(str), df['caption']))

# Запись описания в файлы
for image_file in tqdm(os.listdir(image_dir), desc="Обработка картинок"):
    if '.' not in image_file:
        continue

    uid = image_file.split('.')[0]

    if uid in uid_to_caption:
        caption = uid_to_caption[uid]
        caption_path = os.path.join(caption_dir, image_file + ".txt")
        with open(caption_path, "w", encoding="utf-8") as f:
            f.write(str(caption))
    else:
        print(f"UID {uid} не найдено.")

# %%
# Созранение описаний
for filename in tqdm(os.listdir(caption_dir)):
    new_filename = filename.split(".")
    new_filename = new_filename[0]+"."+new_filename[2]

    filepath_from = os.path.join(caption_dir, filename)
    filepath_to = os.path.join(caption_dir, new_filename)

    # print(filepath_from, filepath_to)
    # break
    os.rename(filepath_from, filepath_to)

# %% [markdown]
# Формирование датасета

# %%
import os
from PIL import Image
import csv
from tqdm.notebook import tqdm

image_dir = r"C:\!project-dataset\images_resize"
# очень нужный файл для датасета!
output_csv = r"C:\!project-dataset\metadata.csv"

with open(output_csv, mode='w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['uid', 'image_width', 'image_height'])  # формат для данной таблицы

    for filename in tqdm(os.listdir(image_dir)):
        if filename.endswith('.jpg'):
            uid = filename.split(".")[0]
            image_path = os.path.join(image_dir, filename)
            with Image.open(image_path) as img:
                width, height = img.size
            writer.writerow([uid, width, height])
